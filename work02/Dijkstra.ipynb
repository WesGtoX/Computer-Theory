# %%
# !pip install googlemaps
# !pip install networkx


import pandas as pd
import googlemaps
from itertools import tee
from __future__ import division
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import networkx as nx
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/3c/3f/25/ce6d7722dba07e5d4a12d27ab38f3d7add65ef43171b02c819
# Successfully built googlemaps
# ...

# %%
locals = []
locals.append('Sebo Desculpe a Poeira')
locals.append('Red Star Sebo Livraria')
locals.append('Sebo Memória')
locals.append('Sebo Bela Cintra')
locals.append('Sebo Praia dos Livros')
locals.append('Sebo do Ferreira')
locals.append('Sebo Perdizes')
locals.append('CASA PUEBLA SEBO')
locals.append('Sebo Cesar')
locals.append('Sebo do Messias')
locals.append('Sebo José de Alencar')
locals.append('Sebo Paulistano')

gmaps = googlemaps.Client(key='AIzaSyD8aOq0DxxJsJ_G0aFB0tRUpZmr7IC5HJY')

caminhos=[]
for i in range(len(locals)):
    for k in range(len(locals)):
            caminhos.append([locals[i], locals[k]])
d_matrix = []
distances = []

for i in range(len(caminhos)):
    distance = gmaps.distance_matrix(caminhos[i][0], caminhos[i][1])['rows'][0]['elements'][0]['distance']['value']
    
    distances.append(distance)
    if len(distances) == len(locals):
        d_matrix.append(distances)
        distances = []

# %%
print('Tabela de código dos nós:\n')
for i in range(len(locals)):
  print(locals[i] + ': ' + str(i))
print('\nMatriz de Distância: \n')
for i in range(len(d_matrix)):
  print(d_matrix[i])
# Out:
# Tabela de código dos nós:
#
# Sebo Desculpe a Poeira: 0
# Red Star Sebo Livraria: 1
# Sebo Memória: 2
# Sebo Bela Cintra: 3
# Sebo Praia dos Livros: 4
# Sebo do Ferreira: 5
# Sebo Perdizes: 6
# CASA PUEBLA SEBO: 7
# Sebo Cesar: 8
# Sebo do Messias: 9
# Sebo José de Alencar: 10
# Sebo Paulistano: 11
#
# Matriz de Distância:
#
# [0, 478, 1794, 4145, 7168, 10433, 6039, 10487, 20307, 7602, 7624, 6322]
# [692, 0, 1316, 3977, 7340, 10887, 5561, 9226, 19829, 6427, 6449, 6154]
# [1451, 1927, 0, 2845, 6790, 11715, 4754, 8677, 18833, 5295, 5318, 5022]
# [4009, 4347, 2864, 0, 9338, 16721, 4032, 11229, 15264, 2963, 2986, 2806]
# [7372, 7848, 6785, 8804, 0, 10268, 11799, 4775, 20275, 7090, 7112, 9690]
# [8740, 9084, 9538, 12164, 8725, 0, 14389, 3168, 25617, 12432, 12454, 15032]
# [6326, 6098, 5498, 4280, 10416, 17800, 0, 12307, 13847, 4014, 4036, 2809]
# [8910, 9255, 7172, 9589, 4280, 4349, 12583, 0, 21060, 7874, 7897, 10475]
# ...

# %%
n_inicial = int(input('Informe o código do nó inicial: '))
n_visitados=[]
tree = []

def dist_calc(path):
  dist = 0
  i=0
  for i in range(len(path) - 1):
    dist = dist + d_matrix[path[i]][path[i+1]]
    
  return dist

i=0
while i < len(d_matrix):
  if i == n_inicial:
    tree.append([i, 0, [i]])
    n_visitados.append(tree[i][0])
  else:
    tree.append([i, -1, []])
  i = i + 1
  
i=0
while i < len(d_matrix):
  tree[i][2] = tree[n_inicial][2][:]
  i = i + 1

n_last = (tree[n_inicial])


while len(n_visitados) < len(tree):
  control = -1
  menor_distancia = -1
  k = 0
  while k < len(tree):
    temp = []
    temp = tree[n_last[0]][2][:]
    temp.append(tree[k][0])
    
    
    if menor_distancia == -1 and tree[k][0] != n_last[0]:
        control = k
        menor_distancia = dist_calc(temp)
        
    elif dist_calc(temp) > tree[k][1] and tree[k][1] != -1 and tree[k][0] not in n_visitados:
        menor_distancia = tree[k][1]
        control = k
        
    if tree[k][1] > dist_calc(temp):
      tree[k][2] = temp[:]
      tree[k][1] = dist_calc(temp)
    k = k + 1

  k = 0
  for k in range(len(tree)):
    temp = []
    temp = tree[n_last[0]][2][:]
    temp.append(tree[k][0])   
    
    if(tree[k][1]) == -1:
      tree[k][1] = d_matrix[n_last[0]][k]
      tree[k][2].append(k)
    
    else:
        if tree[k][1] >  dist_calc(temp):
          tree[k][1] = dist_calc(temp)
          tree[k][2] = temp[:]
    
    if dist_calc(temp) < menor_distancia and tree[k][0] not in n_visitados:
      menor_distancia = dist_calc(temp)
      control = k
      
   
  n_visitados.append(tree[control][0])
  n_last =  tree[control]

print(tree)

i=0
for i in range(len(tree)):
  print('\nNó: ' + locals[i] +'\nCaminho percorrido:')
  
  k=0
  for k in range(len(tree[i][2])):
    if n_inicial == i:
      print('Nó inicial.')
    else:
      print(locals[tree[i][2][k]])
      
  print('Distância do caminho: '+ str(tree[i][1]))
# Out:
# Informe o código do nó inicial: 0
# [[0, 0, [0]], [1, 478, [0, 1]], [2, 1794, [0, 2]], [3, 4145, [0, 3]], [4, 7168, [0, 4]], [5, 10433, [0, 5]], [6, 6039, [0, 6]], [7, 9704, [0, 1, 7]], [8, 19409, [0, 3, 8]], [9, 6905, [0, 1, 9]], [10, 6927, [0, 1, 10]], [11, 6322, [0, 11]]]
#
# Nó: Sebo Desculpe a Poeira
# Caminho percorrido:
# Nó inicial.
# Distância do caminho: 0
#
# Nó: Red Star Sebo Livraria
# Caminho percorrido:
# Sebo Desculpe a Poeira
# Red Star Sebo Livraria
# Distância do caminho: 478
#
# Nó: Sebo Memória
# Caminho percorrido:
# Sebo Desculpe a Poeira
# Sebo Memória
# Distância do caminho: 1794
#
# Nó: Sebo Bela Cintra
# Caminho percorrido:
# Sebo Desculpe a Poeira
# Sebo Bela Cintra
# Distância do caminho: 4145
#
# Nó: Sebo Praia dos Livros
# Caminho percorrido:
# Sebo Desculpe a Poeira
# Sebo Praia dos Livros
# Distância do caminho: 7168
#
# Nó: Sebo do Ferreira
# Caminho percorrido:
# Sebo Desculpe a Poeira
# Sebo do Ferreira
# Distância do caminho: 10433
#
# ...
