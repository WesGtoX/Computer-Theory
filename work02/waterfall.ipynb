# %%
# cach_caracol = {"id": 1, "name": "Cachoeira do Caracol", "latlong": "-29.310803,-50.854238"}
# cach_saltogrande = {"id": 2, "name": "Cachoeira do Salto Grande", "latlong": "-26.392177,-49.355748"}
# cata_iguacu = {"id": 3, "name": "Cataratas do Iguaçu", "latlong": "-25.690346,-54.440839"}
# cach_itambe = {"id": 4, "name": "Cachoeira do Itambé", "latlong": "-21.290040,-47.145398"}
# cach_tabuleiro = {"id": 5, "name": "Cachoeira do Tabuleiro", "latlong": "-19.088765,-43.551510"}
# cach_condedeu = {"id": 6, "name": "Cachoeira Conde D’eu", "latlong": "-22.139910,-42.654060"}
# cach_fumaca = {"id": 7, "name": "Cachoeira da Fumaça", "latlong": "-20.624641,-41.602874"}
# cach_bocadaonca = {"id": 8, "name": "Cachoeira Boca da Onça", "latlong": "-20.740040,-56.734793"}
# cach_veudanoiva = {"id": 9, "name": "Cachoeira Véu da Noiva", "latlong": "-13.856665,-47.454317"}
# cach_santabarbara = {"id": 10, "name": "Cachoeira Santa Bárbara", "latlong": "-13.539699,-47.492756"}
# cach_tororo = {"id": 11, "name": "Cachoeira do Tororó", "latlong": "-15.983273,-47.834249"}
# cach_formiga = {"id": 12, "name": "Cachoeira do Formiga", "latlong": "-10.344702,-46.488353"}

# %%
#import Google Maps and Pandas library
import googlemaps
import config as config
import pandas as pd

# %%
#set the Google Maps Key
gmaps = googlemaps.Client(key=config.maps_apikey)

# %%
#import Origin and Destiny locals
origin = pd.read_csv('locals_coord.csv')
destiny = pd.read_csv('locals_coord.csv')

# %%
#set variables to print Distance Matrix
distance_locals = []
go_to_local = destiny['local'].tolist()
col = ['local']
col += go_to_local

matrix = pd.DataFrame(columns=col)

for i in matrix:
    if i != 'local':
        distance_locals.append(i)
print(distance_locals)
# Out:
# ['Cachoeira do Caracol', 'Cachoeira do Salto Grande', 'Cataratas do Iguacu', 'Cachoeira do Itambe', 'Cachoeira do Tabuleiro', 'Cachoeira Conde Deu', 'Cachoeira da Fumaca', 'Cachoeira Boca da Onca', 'Cachoeira Veu da Noiva', 'Cachoeira Santa Barbara', 'Cachoeira do Tororo', 'Cachoeira do Formiga']

# %%
#loop to generate all distances and print Distance Matrix
distances_matrix = []
for index, l_origin in origin.iterrows():
    info_distance = []
    for index, l_destiny in destiny.iterrows():
        query = gmaps.distance_matrix(l_origin['latlong'], l_destiny['latlong'])
        distance = query['rows'][0]['elements'][0]['distance']['value']

        info_distance.append(distance)

    distances_matrix.append(info_distance)

    info_temp = [l_origin['local']]
    info_temp.extend(info_distance)

    temp = pd.DataFrame([info_temp], columns=col)
    matrix = matrix.append(temp, ignore_index=True)

    print(info_temp)
# Out:
# ['Cachoeira do Caracol', 0, 640811, 949945, 1401670, 1890739, 1683095, 1876670, 1584813, 2389494, 2412956, 2086137, 2970082]
# ['Cachoeira do Salto Grande', 655244, 0, 755519, 821714, 1310782, 1103139, 1296713, 1308429, 1809537, 1832999, 1506180, 2390125]
# ['Cataratas do Iguacu', 950309, 755565, 0, 1076559, 1686875, 1639653, 1833228, 860642, 1876380, 1899842, 1573023, 2456968]
# ['Cachoeira do Itambe', 1402527, 823157, 1075251, 0, 647488, 703937, 848643, 1176039, 1049281, 1072743, 745924, 1629869]
# ['Cachoeira do Tabuleiro', 1889850, 1310480, 1684642, 666973, 0, 608990, 526142, 1758524, 1052001, 1075463, 748644, 1426938]
# ['Cachoeira Conde Deu', 1672630, 1093260, 1627625, 698885, 609927, 0, 277678, 1815932, 1429570, 1453032, 1126213, 1930277]
# ['Cachoeira da Fumaca', 1867680, 1288309, 1822675, 843948, 518337, 277465, 0, 2010982, 1418695, 1442157, 1115338, 1919403]
# ['Cachoeira Boca da Onca', 1585461, 1309184, 856924, 1191968, 1775495, 1827306, 2020880, 0, 1656970, 1680432, 1358071, 2234997]
# ['Cachoeira Veu da Noiva', 2387230, 1807860, 1872348, 1047209, 1053176, 1429588, 1441565, 1656723, 0, 41690, 338379, 664616]
# ['Cachoeira Santa Barbara', 2410692, 1831321, 1895810, 1070671, 1076638, 1453050, 1465027, 1680185, 41690, 0, 361841, 688078]
# ['Cachoeira do Tororo', 2083529, 1504158, 1568647, 743508, 749474, 1125887, 1137864, 1371121, 349531, 372993, 0, 930119]
# ['Cachoeira do Formiga', 2967940, 2388569, 2453058, 1627919, 1419406, 1929356, 1895871, 2234899, 664607, 688069, 919089, 0]

# %%
# print(distances_matrix)

# %%
# #save Distance Matrix on CSV file
# matrix.to_csv('waterfall_file.csv', encoding='utf-8', index=False)
#
# #ret 'local' as line index
# matrix = matrix.set_index('local')

# %%
# Read Distance Matrix CSV, 
waterfall_file = pd.read_csv('waterfall_file.csv')

# Set 'local' as line index and print
waterfall_file = waterfall_file.set_index('local')
waterfall_file
# Out:
#                            Cachoeira do Caracol  Cachoeira do Salto Grande  \
# local
# Cachoeira do Caracol                          0                     640811
# Cachoeira do Salto Grande                655244                          0
# Cataratas do Iguacu                      950303                     755556
# Cachoeira do Itambe                     1402507                     823119
# Cachoeira do Tabuleiro                  1889810                    1310422
# Cachoeira Conde Deu                     1672610                    1093223
# Cachoeira da Fumaca                     1867660                    1288273
# Cachoeira Boca da Onca                  1585455                    1309175
# Cachoeira Veu da Noiva                  2387210                    1807823
# Cachoeira Santa Barbara                 2410672                    1831285
# Cachoeira do Tororo                     2083509                    1504122
# Cachoeira do Formiga                    2967920                    2388533
#
#                            Cataratas do Iguacu  Cachoeira do Itambe  \
# local
# Cachoeira do Caracol                    949940              1401665
# Cachoeira do Salto Grande               755514               821714
# Cataratas do Iguacu                          0              1076559
# Cachoeira do Itambe                    1075251                    0
# Cachoeira do Tabuleiro                 1684621               666952
# Cachoeira Conde Deu                    1627624               698885
# Cachoeira da Fumaca                    1822674               842094
# Cachoeira Boca da Onca                  856924              1191968
# Cachoeira Veu da Noiva                 1872426              1047209
# Cachoeira Santa Barbara                1895888              1070671
# Cachoeira do Tororo                    1568725               743508
# Cachoeira do Formiga                   2453136              1627919
#
#                            Cachoeira do Tabuleiro  Cachoeira Conde Deu  \
# local
# Cachoeira do Caracol                      1890715              1683091
# Cachoeira do Salto Grande                 1310764              1103140
# Cataratas do Iguacu                       1686855              1639653
# Cachoeira do Itambe                        647468               703937
# Cachoeira do Tabuleiro                          0               608969
# Cachoeira Conde Deu                        609908                    0
# Cachoeira da Fumaca                        518337               277465
# Cachoeira Boca da Onca                    1761466              1827306
# Cachoeira Veu da Noiva                    1053176              1429588
# Cachoeira Santa Barbara                   1076638              1453050
# Cachoeira do Tororo                        749474              1125887
# Cachoeira do Formiga                      1419406              1929356
#                     [2410692, 1831321, 1895810, 1070671, 1076638, 1453050, 1465027, 1680185, 41690, 0, 361841, 688078],
#                     [2083529, 1504158, 1568647, 743508, 749474, 1125887, 1137864, 1371121, 349531, 372993, 0, 930119],
#                     [2967940, 2388569, 2453058, 1627919, 1419406, 1929356, 1895871, 2234899, 664607, 688069, 919089, 0]]

# %%
dist_best_route = []
best_route_name = []
index_best_route = [0]
i = 0
control = -1

# %%
#loop to get the nearest neighbor
while len(index_best_route) != 12:
    minus_route = -1
    for d in range(len(distances_matrix[i])):
        if d != i and minus_route == -1:
            if d not in index_best_route:
                minus_route = distances_matrix[i][d]
                control = d
        if minus_route != -1 and minus_route > distances_matrix[i][d] and d != i:
            if d not in index_best_route:
                minus_route = distances_matrix[i][d]
                control = d

    #attach nearest neighbor by index
    index_best_route.append(control)
    #attach nearest neighbor by distance
    dist_best_route.append(minus_route)
    i = control

# %%
#attach nearest neighbor by waterfall name
for i in range(len(index_best_route)):
    best_route_name.append(distance_locals[index_best_route[i]])

waterfall_distance = 0
for i in range(len(dist_best_route)):
    waterfall_distance = waterfall_distance + dist_best_route[i]

# %%
#print route on screen
i = 0
for i in range(len(dist_best_route)):
    print({"From": best_route_name[i], "To": best_route_name[i+1], "Distance": dist_best_route[i]})
    i+=1
# Out:
# {'From': 'Cachoeira do Caracol', 'To': 'Cachoeira do Salto Grande', 'Distance': 640811}
# {'From': 'Cachoeira do Salto Grande', 'To': 'Cataratas do Iguacu', 'Distance': 755519}
# {'From': 'Cataratas do Iguacu', 'To': 'Cachoeira Boca da Onca', 'Distance': 860642}
# {'From': 'Cachoeira Boca da Onca', 'To': 'Cachoeira do Itambe', 'Distance': 1191968}
# {'From': 'Cachoeira do Itambe', 'To': 'Cachoeira do Tabuleiro', 'Distance': 647488}
# {'From': 'Cachoeira do Tabuleiro', 'To': 'Cachoeira da Fumaca', 'Distance': 526142}
# {'From': 'Cachoeira da Fumaca', 'To': 'Cachoeira Conde Deu', 'Distance': 277465}
# {'From': 'Cachoeira Conde Deu', 'To': 'Cachoeira do Tororo', 'Distance': 1126213}
# {'From': 'Cachoeira do Tororo', 'To': 'Cachoeira Veu da Noiva', 'Distance': 349531}
# {'From': 'Cachoeira Veu da Noiva', 'To': 'Cachoeira Santa Barbara', 'Distance': 41690}
# {'From': 'Cachoeira Santa Barbara', 'To': 'Cachoeira do Formiga', 'Distance': 688078}

# %%
print("\nLista - Melhor Rota: Distância:")
print(dist_best_route)

print("\nLista - Melhor Rota: Index:")
print(dist_best_route)

print("\nLista - Melhor Rota: Cachoeiras:")
print(index_best_route)

print("\nDistância total:")
print("KM: {:.3f}, Metros: {}, Milhas: {:.3f}".format((waterfall_distance / 1000), (waterfall_distance), (waterfall_distance / 1609.344)))
# Out:
# Lista - Melhor Rota: Distância:
# [640811, 755519, 860642, 1191968, 647488, 526142, 277465, 1126213, 349531, 41690, 688078]
#
# Lista - Melhor Rota: Index:
# [640811, 755519, 860642, 1191968, 647488, 526142, 277465, 1126213, 349531, 41690, 688078]
#
# Lista - Melhor Rota: Cachoeiras:
# [0, 1, 2, 7, 3, 4, 6, 5, 10, 8, 9, 11]
#
# Distância total:
# KM: 7105.547, Metros: 7105547, Milhas: 4415.182
